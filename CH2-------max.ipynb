# %%
joke="秉豪,豪,夢遊仙境"
joke.split(',')
# Out:
# ['秉豪', '豪', '夢遊仙境']

# %%
news='''即日起，購買外套2+1組合
任選2件再送你1件外套！
超級划算！怎能錯過！！~~'''

# %%
len(news)
# Out:
# 40

# %%
news[0:5]
# Out:
# '即日起，購'

# %%
word='2'
news.count(word)
# Out:
# 2

# %%
import requests
response=requests.get("http://www.novelscape.net/wg/g/genaidinei/jlyx/001.htm")
response.encoding="big5"
print(response.text)
# Out:
# <HTML><HEAD><meta http-equiv="Content-Type" content="text/html; charset=big5"><TITLE>拉爾夫·格萊迪內-->极樂游戲-->其人出山</TITLE>
# <META NAME="keywords" CONTENT="拉爾夫·格萊迪內 极樂游戲 其人出山">
# <META NAME="description" CONTENT="拉爾夫·格萊迪內 - 极樂游戲 - 其人出山">
#
# <style>
# <!--
# #page {position:absolute; z-index:0; left:0px; top:0px}
# .tt3 {font: 9pt/12pt "宋体"}
# .tt2 {font: 12pt/15pt "宋体"}
# a {text-decoration:none}
# a:hover {color: blue;text-decoration:underline}
# -->
# </style>
# </HEAD>
# <body text="#000000" link="#0000EE" vlink="#0000EE" alink="#FF0000" bgcolor="#F1F1F3" leftmargin="3" topmargin="3" marginheight="3" marginwidth="3">
# <center><table WIDTH="720" >
# <tr ALIGN=CENTER>
# <td WIDTH="100%">
# <center><table BORDER=0 CELLSPACING=0 CELLPADDING=0 >
# <tr>
# <td><script src="../../../../ad/text01.js"></script>
# </td>
# </tr>
# </table></center>
# </td>
# </tr>
# </table></center><TABLE WIDTH="100%" CELLPADDING=10 CELLSPACING=0 BORDER=0>
# <TR>
# ...

# %%
a=response.text
port="一"
a.count(port)
# Out:
# 140

# %%
len(a)
# Out:
# 8141
